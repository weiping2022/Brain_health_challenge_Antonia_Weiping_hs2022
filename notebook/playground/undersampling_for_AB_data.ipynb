# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import f1_score
from sklearn.tree import export_text
import mglearn
from dashboard_one import *
from dash_model_two import *
from feature_selection import *
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# %%
df = pd.read_csv('main_file_1206_wz.csv').iloc[:,1:].drop(['NPIKSEV'],axis=1)
df
# Out:
#         RID DIAG VISCODE2        PTID   AGE PTGENDER  PTEDUCAT  Phase  \
# 0         1  NaN      NaN         NaN   NaN      NaN       NaN    NaN
# 1         2   NL       sc  011_S_0002  74.3     Male      16.0  ADNI1
# 2         2   NL       bl  011_S_0002  74.3     Male      16.0  ADNI1
# 3         2   NL      m06  011_S_0002  74.3     Male      16.0  ADNI1
# 4         2   NL      m36  011_S_0002  74.3     Male      16.0  ADNI1
# ...     ...  ...      ...         ...   ...      ...       ...    ...
# 22807  7102   NL       sc  341_S_7102   NaN      NaN       NaN  ADNI3
# 22808  7103   NL       sc  013_S_7103   NaN      NaN       NaN  ADNI3
# 22809  7104   NL       sc  153_S_7104   NaN      NaN       NaN  ADNI3
# 22810  7105  MCI       sc  035_S_7105   NaN      NaN       NaN  ADNI3
# 22811  7106  MCI       sc  941_S_7106   NaN      NaN       NaN  ADNI3
#
#          EXAMDATE  Ventricles  ...  NPIK7  NPIK8  NPIK9A  NPIK9B  NPIK9C  \
# 0             NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
# 1      2005-08-09    118233.0  ...    NaN    NaN     NaN     NaN     NaN
# 2      2005-08-09    118233.0  ...    NaN    NaN     NaN     NaN     NaN
# 3      2006-06-03    118233.0  ...    NaN    NaN     NaN     NaN     NaN
# 4      2008-08-27    118233.0  ...    NaN    NaN     NaN     NaN     NaN
# ...           ...         ...  ...    ...    ...     ...     ...     ...
# 22807         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
# 22808         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
# 22809         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
# 22810         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
# 22811         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
#
#        NPIKTOT  OSA  PREV_DIAG  DIAG_CHANGED  DIAG_GROUP
# 0          NaN  NaN        NaN         False         NaN
# 1          NaN  0.0         NL         False       NL-NL
# 2          NaN  0.0         NL         False       NL-NL
# 3          NaN  0.0         NL         False       NL-NL
# 4          NaN  0.0         NL         False       NL-NL
# ...        ...  ...        ...           ...         ...
# 22807      NaN  0.0         NL         False       NL-NL
# 22808      NaN  0.0         NL         False       NL-NL
# 22809      NaN  0.0         NL         False       NL-NL
# 22810      NaN  0.0        MCI         False     MCI-MCI
# 22811      NaN  0.0        MCI         False     MCI-MCI
#
# [22812 rows x 66 columns]

# %%
ml_cols = ['DIAG','insomnia', 'OSA', 
'ratio_Ventricles_bl',
'ratio_Hippocampus_bl', 'ratio_WholeBrain_bl', 'ratio_Entorhinal_bl',
'ratio_Fusiform_bl', 'ratio_ICV_bl','NPIKTOT','ABETA','TAU']

 

ml_df_clean = df.loc[(df.DIAG_GROUP == 'MCI-AD')|(df.DIAG_GROUP == 'NL-AD'), ml_cols]
ml_df_clean = ml_df_clean.dropna(thresh=9) 
ml_df_clean = ml_df_clean.dropna()
ml_df_clean = pd.get_dummies(ml_df_clean)
ml_df_clean
# Out:
#        insomnia  OSA  ratio_Ventricles_bl  ratio_Hippocampus_bl  \
# 951         0.0  0.0             1.304612              0.809341
# 1521        0.0  0.0             1.313395              0.936196
# 1712        0.0  1.0             1.135662              0.963142
# 1748        0.0  0.0             1.332818              0.963784
# 1820        0.0  0.0             1.062252              0.896487
# 1983        0.0  0.0             1.069613              1.045302
# 2233        0.0  0.0             1.363578              0.880237
# 3616        0.0  1.0             1.218474              0.884068
# 5983        0.0  0.0             1.218141              0.920640
# 6375        0.0  0.0             1.227220              0.945489
# 10838       0.0  1.0             1.801204              0.725198
# 12108       0.0  0.0             1.659449              0.758405
# 12504       0.0  0.0             1.087506              0.987311
# 13528       0.0  0.0             1.247975              0.865023
# 14013       0.0  0.0             1.297811              0.843043
# 14633       0.0  0.0             1.177642              0.978786
# 14645       0.0  0.0             1.353792              0.922149
# 14783       0.0  1.0             1.044784              0.987373
# 15435       0.0  0.0             1.030694              0.925032
# 15753       0.0  0.0             1.072679              0.975585
# 15979       0.0  1.0             1.340513              0.960222
# 16152       0.0  0.0             1.072872              1.024646
# 16826       0.0  0.0             1.252423              0.968695
# 17442       0.0  1.0             1.171577              0.973101
# 17496       0.0  0.0             1.058146              0.993635
# 17498       0.0  0.0             1.095057              0.963588
#
#        ratio_WholeBrain_bl  ratio_Entorhinal_bl  ratio_Fusiform_bl  \
# 951               0.920264             0.792420           0.876517
# 1521              0.951237             0.853022           0.933932
# 1712              1.000129             0.767836           0.967306
# 1748              0.982598             0.720396           0.864626
# 1820              0.974781             0.622315           0.886466
# 1983              0.996339             0.882086           1.158639
# 2233              0.943468             0.744767           0.878624
# 3616              0.967732             0.738691           0.824111
# 5983              1.000114             1.173745           0.998347
# 6375              0.965867             0.938491           0.986595
# 10838             0.989410             0.636803           0.933678
# 12108             0.958027             0.912856           0.951914
# 12504             0.985094             1.066690           0.949864
# 13528             0.957931             0.765144           0.951666
# 14013             0.930743             0.914143           0.908888
# 14633             0.981754             0.987797           0.937276
# 14645             0.955625             0.824213           0.870882
# 14783             1.000910             1.054444           1.052694
# 15435             0.991637             0.862729           0.833800
# 15753             0.988866             0.974466           0.964826
# 15979             0.981036             0.972599           1.030216
# 16152             0.977278             0.998594           0.977811
# 16826             0.983882             0.910064           0.968844
# 17442             0.991091             0.936357           0.956102
# 17496             0.982035             0.997073           0.954417
# 17498             0.976782             0.956980           0.946115
#
#        ratio_ICV_bl  NPIKTOT   ABETA    TAU  DIAG_AD
# 951        1.017161      1.0   560.0  253.9        1
# 1521       1.007571      3.0   543.5  495.6        1
# 1712       1.003015      8.0   279.2  277.5        1
# 1748       1.011185      8.0   396.8  247.2        1
# 1820       0.995158      4.0   500.1  308.6        1
# 1983       0.998642      4.0  1474.0  313.0        1
# 2233       1.002655      1.0   486.1  403.3        1
# 3616       1.011852      6.0   498.5  277.8        1
# 5983       1.017902      4.0   608.7  382.0        1
# 6375       1.000617      8.0   878.3  267.0        1
# 10838      0.994214      6.0   426.3  216.8        1
# 12108      1.012748      6.0   544.5  279.7        1
# 12504      0.993804      1.0  1533.0  145.1        1
# 13528      1.007079      4.0   584.6  364.9        1
# 14013      0.986853      8.0   222.8  143.3        1
# 14633      0.993257      3.0   811.5  495.9        1
# 14645      1.001144      6.0   351.6  805.7        1
# 14783      1.001330      6.0  1253.0  164.7        1
# 15435      0.991317      3.0   256.2  409.9        1
# 15753      0.979157      2.0   477.8  267.5        1
# 15979      1.009752      3.0   629.2  310.4        1
# 16152      0.999911      8.0   550.1  299.1        1
# 16826      1.025355      9.0   661.1  506.5        1
# 17442      0.996148      8.0   472.3  195.4        1
# 17496      0.999497      6.0   525.0  308.8        1
# 17498      0.993128      6.0   525.0  308.8        1

# %%
ml_df_clean.shape
# Out:
# (26, 12)

# %%
# some codes are probably missing. The dataframe has only DIAG_AD as 1. And dataframe is too small.
# my version
ml_cols = ['DIAG','insomnia', 'OSA', 
'ratio_Ventricles_bl',
'ratio_Hippocampus_bl', 'ratio_WholeBrain_bl', 'ratio_Entorhinal_bl',
'ratio_Fusiform_bl', 'ratio_ICV_bl','NPIKTOT','NPIK9A','NPIK9B','NPIK9C','DIAG_GROUP']

 
ml_df_clean = df[ml_cols]

# new feature DIAG_AD
ml_df_clean['DIAG_AD'] = np.nan
ml_df_clean.loc[ml_df_clean.DIAG == 'NL' ,'DIAG_AD'] = 0
ml_df_clean.loc[ml_df_clean.DIAG == 'MCI' ,'DIAG_AD'] = 0
ml_df_clean.loc[ml_df_clean.DIAG == 'AD' ,'DIAG_AD'] = 1
# drop some features
ml_df_clean = ml_df_clean.drop(['NPIK9A','NPIK9B','NPIK9C','DIAG','DIAG_GROUP'],axis=1)
ml_df_clean = ml_df_clean.dropna().reset_index(drop=True)
ml_df_clean
# Out:
# <ipython-input-32-befcf8709995>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml_df_clean['DIAG_AD'] = np.nan
# C:\Users\weipi\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#       insomnia  OSA  ratio_Ventricles_bl  ratio_Hippocampus_bl  \
# 0          0.0  0.0             1.000000              1.000000
# 1          0.0  0.0             1.000000              1.000000
# 2          0.0  0.0             0.973557              0.993421
# 3          0.0  0.0             0.973557              0.993421
# 4          0.0  0.0             0.973557              0.993421
# ...        ...  ...                  ...                   ...
# 5590       0.0  0.0             1.000000              1.000000
# 5591       0.0  0.0             1.000000              1.000000
# 5592       0.0  0.0             1.000000              1.000000
# 5593       0.0  0.0             1.000000              1.000000
# 5594       0.0  0.0             1.000000              1.000000
#
#       ratio_WholeBrain_bl  ratio_Entorhinal_bl  ratio_Fusiform_bl  \
# 0                1.000000              1.00000           1.000000
# 1                1.000000              1.00000           1.000000
# 2                0.990747              0.82315           1.015951
# 3                0.990747              0.82315           1.015951
# 4                0.990747              0.82315           1.015951
# ...                   ...                  ...                ...
# 5590             1.000000              1.00000           1.000000
# 5591             1.000000              1.00000           1.000000
# 5592             1.000000              1.00000           1.000000
# 5593             1.000000              1.00000           1.000000
# 5594             1.000000              1.00000           1.000000
#
#       ratio_ICV_bl  NPIKTOT  DIAG_AD
# 0         1.000000      6.0      0.0
# 1         1.000000      6.0      0.0
# 2         0.994563      6.0      0.0
# 3         0.994563      6.0      0.0
# 4         0.994563      6.0      0.0
# ...            ...      ...      ...
# 5590      1.000000      3.0      0.0
# 5591      1.000000      2.0      0.0
# 5592      1.000000      2.0      0.0
# 5593      1.000000      1.0      0.0
# 5594      1.000000      1.0      0.0
#
# [5595 rows x 10 columns]

# %%
ml_df_clean.shape
# Out:
# (5595, 10)

# %%
rus = RandomUnderSampler(random_state=432)
X_undersampled, y_unsampled = rus.fit_resample(ml_df_clean, ml_df_clean['DIAG_AD'])
X_undersampled.to_csv('ml_df_clean_undersampled.csv')
X_undersampled.groupby('DIAG_AD').count()
# Out:
#          insomnia  OSA  ratio_Ventricles_bl  ratio_Hippocampus_bl  \
# DIAG_AD
# 0.0           798  798                  798                   798
# 1.0           798  798                  798                   798
#
#          ratio_WholeBrain_bl  ratio_Entorhinal_bl  ratio_Fusiform_bl  \
# DIAG_AD
# 0.0                      798                  798                798
# 1.0                      798                  798                798
#
#          ratio_ICV_bl  NPIKTOT
# DIAG_AD
# 0.0               798      798
# 1.0               798      798

# %%
drop_lst = ['DIAG_AD']
target = 'DIAG_AD'
k = 10
cv_models(ml_df_clean,drop_lst,target,k)
# Out:
# After undersampling data size is 1596 ; Resampled dataset shape Counter({0.0: 798, 1.0: 798})
#
# 6 principle components are needed to explain 90% of the data
#
# - Using original dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.592
#           - saga_L1, average weighted f1-score of 10-cross validation:0.333
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.592
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.603
#           - saga_L1, average weighted f1-score of 10-cross validation:0.611
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.603
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.650
#           - saga_L1, average weighted f1-score of 10-cross validation:0.650
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.650
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.673
#           - saga_L1, average weighted f1-score of 10-cross validation:0.675
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.673
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.676
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.676
#           - saga_L1, average weighted f1-score of 10-cross validation:0.677
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.676
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.678
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.556
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.646
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.642
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.653
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.676
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.672
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.702
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.703
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.712
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.706
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.701
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.700
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.710
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.705
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.737
#           - 10trees. average weighted f1-score of 10-cross validation:0.722
#           - 15trees. average weighted f1-score of 10-cross validation:0.738
#           - 20trees. average weighted f1-score of 10-cross validation:0.731
#           - 25trees. average weighted f1-score of 10-cross validation:0.753
#           - 30trees. average weighted f1-score of 10-cross validation:0.737
#           - 35trees. average weighted f1-score of 10-cross validation:0.746
#           - 40trees. average weighted f1-score of 10-cross validation:0.736
#           - 45trees. average weighted f1-score of 10-cross validation:0.739
#           - 50trees. average weighted f1-score of 10-cross validation:0.733
#           - 55trees. average weighted f1-score of 10-cross validation:0.730
#           - 60trees. average weighted f1-score of 10-cross validation:0.736
#           - 65trees. average weighted f1-score of 10-cross validation:0.733
#           - 70trees. average weighted f1-score of 10-cross validation:0.735
#           - 75trees. average weighted f1-score of 10-cross validation:0.738
#           - 80trees. average weighted f1-score of 10-cross validation:0.733
#           - 85trees. average weighted f1-score of 10-cross validation:0.731
#           - 90trees. average weighted f1-score of 10-cross validation:0.733
#           - 95trees. average weighted f1-score of 10-cross validation:0.739
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.702
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.671
# - Using scaled dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.648
#           - saga_L1, average weighted f1-score of 10-cross validation:0.333
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.648
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.673
#           - saga_L1, average weighted f1-score of 10-cross validation:0.644
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.673
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.675
#           - saga_L1, average weighted f1-score of 10-cross validation:0.674
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.675
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.677
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.677
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.677
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.677
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.556
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.646
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.642
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.653
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.676
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.672
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.702
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.703
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.712
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.706
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.701
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.700
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.710
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.705
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.737
#           - 10trees. average weighted f1-score of 10-cross validation:0.722
#           - 15trees. average weighted f1-score of 10-cross validation:0.738
#           - 20trees. average weighted f1-score of 10-cross validation:0.731
#           - 25trees. average weighted f1-score of 10-cross validation:0.752
#           - 30trees. average weighted f1-score of 10-cross validation:0.737
#           - 35trees. average weighted f1-score of 10-cross validation:0.746
#           - 40trees. average weighted f1-score of 10-cross validation:0.734
#           - 45trees. average weighted f1-score of 10-cross validation:0.739
#           - 50trees. average weighted f1-score of 10-cross validation:0.733
#           - 55trees. average weighted f1-score of 10-cross validation:0.730
#           - 60trees. average weighted f1-score of 10-cross validation:0.736
#           - 65trees. average weighted f1-score of 10-cross validation:0.735
#           - 70trees. average weighted f1-score of 10-cross validation:0.735
#           - 75trees. average weighted f1-score of 10-cross validation:0.738
#           - 80trees. average weighted f1-score of 10-cross validation:0.733
#           - 85trees. average weighted f1-score of 10-cross validation:0.731
#           - 90trees. average weighted f1-score of 10-cross validation:0.733
#           - 95trees. average weighted f1-score of 10-cross validation:0.739
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.719
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.705
# - Using 6 pca-components:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.645
#           - saga_L1, average weighted f1-score of 10-cross validation:0.333
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.645
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.663
#           - saga_L1, average weighted f1-score of 10-cross validation:0.644
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.663
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.670
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.677
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.677
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.677
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.677
#           - saga_L1, average weighted f1-score of 10-cross validation:0.677
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.677
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.578
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.609
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.654
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.650
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.659
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.672
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.687
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.694
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.684
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.691
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.689
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.689
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.690
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.682
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.717
#           - 10trees. average weighted f1-score of 10-cross validation:0.713
#           - 15trees. average weighted f1-score of 10-cross validation:0.715
#           - 20trees. average weighted f1-score of 10-cross validation:0.711
#           - 25trees. average weighted f1-score of 10-cross validation:0.717
#           - 30trees. average weighted f1-score of 10-cross validation:0.711
#           - 35trees. average weighted f1-score of 10-cross validation:0.704
#           - 40trees. average weighted f1-score of 10-cross validation:0.703
#           - 45trees. average weighted f1-score of 10-cross validation:0.712
#           - 50trees. average weighted f1-score of 10-cross validation:0.706
#           - 55trees. average weighted f1-score of 10-cross validation:0.706
#           - 60trees. average weighted f1-score of 10-cross validation:0.711
#           - 65trees. average weighted f1-score of 10-cross validation:0.716
#           - 70trees. average weighted f1-score of 10-cross validation:0.711
#           - 75trees. average weighted f1-score of 10-cross validation:0.712
#           - 80trees. average weighted f1-score of 10-cross validation:0.711
#           - 85trees. average weighted f1-score of 10-cross validation:0.711
#           - 90trees. average weighted f1-score of 10-cross validation:0.713
#           - 95trees. average weighted f1-score of 10-cross validation:0.712
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.699
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.694

# %%
# 25trees. average weighted f1-score of 10-cross validation:0.753
n = 25
res = usampling_scale_data(ml_df_clean,drop_lst,target)  
lst = ['insomnia', 'OSA', 'ratio_Ventricles_bl', 'ratio_Hippocampus_bl',
       'ratio_WholeBrain_bl', 'ratio_Entorhinal_bl', 'ratio_Fusiform_bl',
       'ratio_ICV_bl', 'NPIKTOT']
X_ = res[0]  # unscaled input
y_ = res[3]
clf = RandomForestClassifier(n_estimators =n, random_state = 5862)
title_label = '{}-fold crossvalidation random forest ({} trees)'.format(k,n)
feature_importance(X_,y_,clf,k,title_label)
plt.suptitle('Target: AD 798; not AD 798')

# plot the diagnosis distribution 
df_new = X_.copy()
df_new[target] = y_
f,axes = plt.subplots(nrows = 3,ncols=3,figsize=(18,12))
axes = axes.ravel()


for i in range(len(lst)):
    ax = sns.boxplot(data=df_new, y=lst[i],x= target,ax = axes[i])
    ax.set(xlabel='Diagnosis AD')
# Out:
# After undersampling data size is 1596 ; Resampled dataset shape Counter({0.0: 798, 1.0: 798})
#
# 6 principle components are needed to explain 90% of the data
#
# Features sorted by their score for each estimator

# %%
# not use insomnia and OSA

drop_lst = ['DIAG_AD','OSA','insomnia']
target = 'DIAG_AD'
k = 10
cv_models(ml_df_clean,drop_lst,target,k)
# Out:
# After undersampling data size is 1596 ; Resampled dataset shape Counter({0.0: 798, 1.0: 798})
#
# 4 principle components are needed to explain 90% of the data
#
# - Using original dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.601
#           - saga_L1, average weighted f1-score of 10-cross validation:0.333
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.601
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.603
#           - saga_L1, average weighted f1-score of 10-cross validation:0.611
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.603
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.660
#           - saga_L1, average weighted f1-score of 10-cross validation:0.656
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.660
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.663
#           - saga_L1, average weighted f1-score of 10-cross validation:0.666
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.663
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.672
#           - saga_L1, average weighted f1-score of 10-cross validation:0.669
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.672
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.670
#           - saga_L1, average weighted f1-score of 10-cross validation:0.669
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.670
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.670
#           - saga_L1, average weighted f1-score of 10-cross validation:0.669
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.670
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.556
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.646
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.645
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.663
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.677
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.666
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.685
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.685
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.698
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.693
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.710
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.715
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.705
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.713
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.732
#           - 10trees. average weighted f1-score of 10-cross validation:0.728
#           - 15trees. average weighted f1-score of 10-cross validation:0.737
#           - 20trees. average weighted f1-score of 10-cross validation:0.738
#           - 25trees. average weighted f1-score of 10-cross validation:0.747
#           - 30trees. average weighted f1-score of 10-cross validation:0.738
#           - 35trees. average weighted f1-score of 10-cross validation:0.745
#           - 40trees. average weighted f1-score of 10-cross validation:0.744
#           - 45trees. average weighted f1-score of 10-cross validation:0.744
#           - 50trees. average weighted f1-score of 10-cross validation:0.746
#           - 55trees. average weighted f1-score of 10-cross validation:0.748
#           - 60trees. average weighted f1-score of 10-cross validation:0.744
#           - 65trees. average weighted f1-score of 10-cross validation:0.751
#           - 70trees. average weighted f1-score of 10-cross validation:0.750
#           - 75trees. average weighted f1-score of 10-cross validation:0.751
#           - 80trees. average weighted f1-score of 10-cross validation:0.751
#           - 85trees. average weighted f1-score of 10-cross validation:0.750
#           - 90trees. average weighted f1-score of 10-cross validation:0.746
#           - 95trees. average weighted f1-score of 10-cross validation:0.749
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.683
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.666
# - Using scaled dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.646
#           - saga_L1, average weighted f1-score of 10-cross validation:0.333
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.646
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.667
#           - saga_L1, average weighted f1-score of 10-cross validation:0.643
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.667
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.672
#           - saga_L1, average weighted f1-score of 10-cross validation:0.671
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.672
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.670
#           - saga_L1, average weighted f1-score of 10-cross validation:0.670
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.670
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.670
#           - saga_L1, average weighted f1-score of 10-cross validation:0.670
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.670
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.670
#           - saga_L1, average weighted f1-score of 10-cross validation:0.670
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.670
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.670
#           - saga_L1, average weighted f1-score of 10-cross validation:0.670
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.670
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.556
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.646
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.645
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.663
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.677
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.666
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.685
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.685
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.698
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.693
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.710
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.715
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.705
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.713
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.732
#           - 10trees. average weighted f1-score of 10-cross validation:0.728
#           - 15trees. average weighted f1-score of 10-cross validation:0.736
#           - 20trees. average weighted f1-score of 10-cross validation:0.738
#           - 25trees. average weighted f1-score of 10-cross validation:0.747
#           - 30trees. average weighted f1-score of 10-cross validation:0.738
#           - 35trees. average weighted f1-score of 10-cross validation:0.745
#           - 40trees. average weighted f1-score of 10-cross validation:0.744
#           - 45trees. average weighted f1-score of 10-cross validation:0.744
#           - 50trees. average weighted f1-score of 10-cross validation:0.746
#           - 55trees. average weighted f1-score of 10-cross validation:0.748
#           - 60trees. average weighted f1-score of 10-cross validation:0.743
#           - 65trees. average weighted f1-score of 10-cross validation:0.751
#           - 70trees. average weighted f1-score of 10-cross validation:0.749
#           - 75trees. average weighted f1-score of 10-cross validation:0.751
#           - 80trees. average weighted f1-score of 10-cross validation:0.750
#           - 85trees. average weighted f1-score of 10-cross validation:0.750
#           - 90trees. average weighted f1-score of 10-cross validation:0.746
#           - 95trees. average weighted f1-score of 10-cross validation:0.748
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.733
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.699
# - Using 4 pca-components:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.645
#           - saga_L1, average weighted f1-score of 10-cross validation:0.333
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.645
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.651
#           - saga_L1, average weighted f1-score of 10-cross validation:0.637
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.651
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.663
#           - saga_L1, average weighted f1-score of 10-cross validation:0.658
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.663
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.660
#           - saga_L1, average weighted f1-score of 10-cross validation:0.662
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.660
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.660
#           - saga_L1, average weighted f1-score of 10-cross validation:0.660
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.660
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.660
#           - saga_L1, average weighted f1-score of 10-cross validation:0.660
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.660
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.660
#           - saga_L1, average weighted f1-score of 10-cross validation:0.660
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.660
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.580
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.599
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.644
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.667
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.679
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.669
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.666
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.676
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.691
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.686
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.691
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.691
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.689
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.700
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.721
#           - 10trees. average weighted f1-score of 10-cross validation:0.697
#           - 15trees. average weighted f1-score of 10-cross validation:0.727
#           - 20trees. average weighted f1-score of 10-cross validation:0.719
#           - 25trees. average weighted f1-score of 10-cross validation:0.715
#           - 30trees. average weighted f1-score of 10-cross validation:0.713
#           - 35trees. average weighted f1-score of 10-cross validation:0.713
#           - 40trees. average weighted f1-score of 10-cross validation:0.710
#           - 45trees. average weighted f1-score of 10-cross validation:0.714
#           - 50trees. average weighted f1-score of 10-cross validation:0.715
#           - 55trees. average weighted f1-score of 10-cross validation:0.713
#           - 60trees. average weighted f1-score of 10-cross validation:0.719
#           - 65trees. average weighted f1-score of 10-cross validation:0.714
#           - 70trees. average weighted f1-score of 10-cross validation:0.715
#           - 75trees. average weighted f1-score of 10-cross validation:0.715
#           - 80trees. average weighted f1-score of 10-cross validation:0.713
#           - 85trees. average weighted f1-score of 10-cross validation:0.716
#           - 90trees. average weighted f1-score of 10-cross validation:0.713
#           - 95trees. average weighted f1-score of 10-cross validation:0.713
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.684
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.692

# %%
# - 65trees. average weighted f1-score of 10-cross validation:0.751
n = 65
res = usampling_scale_data(ml_df_clean,drop_lst,target)  
lst = ['ratio_Ventricles_bl', 'ratio_Hippocampus_bl',
       'ratio_WholeBrain_bl', 'ratio_Entorhinal_bl', 'ratio_Fusiform_bl',
       'ratio_ICV_bl', 'NPIKTOT']
X_ = res[0]  # unscaled input
y_ = res[3]
clf = RandomForestClassifier(n_estimators =n, random_state = 5862)
title_label = '{}-fold crossvalidation random forest ({} trees)'.format(k,n)
feature_importance(X_,y_,clf,k,title_label)
plt.suptitle('Target: AD 798; not AD 798')

# plot the diagnosis distribution 
df_new = X_.copy()
df_new[target] = y_
f,axes = plt.subplots(nrows = len(lst)//3+1,ncols=3,figsize=(18,12))
axes = axes.ravel()


for i in range(len(lst)):
    ax = sns.boxplot(data=df_new, y=lst[i],x= target,ax = axes[i])
    ax.set(xlabel='Diagnosis AD')
# Out:
# After undersampling data size is 1596 ; Resampled dataset shape Counter({0.0: 798, 1.0: 798})
#
# 4 principle components are needed to explain 90% of the data
#
# Features sorted by their score for each estimator

# %%
X = SS.fit_transform(ml_df_clean[['ratio_Ventricles_bl',
'ratio_Hippocampus_bl', 'ratio_WholeBrain_bl', 'ratio_Entorhinal_bl',
'ratio_Fusiform_bl', 'ratio_ICV_bl', 'NPIKTOT']])
y = ml_df_clean.DIAG_AD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0a7571093766> in <module>
# ----> 1 X = SS.fit_transform(ml_df_clean[['ratio_Ventricles_bl',
#       2 'ratio_Hippocampus_bl', 'ratio_WholeBrain_bl', 'ratio_Entorhinal_bl',
#       3 'ratio_Fusiform_bl', 'ratio_ICV_bl', 'NPIKTOT']])
#       4 y = ml_df_clean.DIAG_AD
#
# NameError: name 'SS' is not defined
