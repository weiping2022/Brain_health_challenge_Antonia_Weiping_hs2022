# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import f1_score
from sklearn.tree import export_text
import mglearn
from dashboard_two import *
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# %% [markdown]
# ### brain volume_____VS_____diagnosischanges from every visit

# %%
com_col = ['Phase', 'RID', 'VISCODE2','PTID']
target = 'DIAG_GROUP'

# %%
df = pd.read_csv('../data/main_file_final.csv').drop(['NPIKSEV'],axis=1)
df = df[df['DIAG_GROUP'].notna()].reset_index(drop=True)   # keep the rows where DXCHANGE is not nan
df
# Out:
#         RID DIAG VISCODE2        PTID   AGE PTGENDER  PTEDUCAT  Phase  \
# 0         2   NL       sc  011_S_0002  74.3     Male      16.0  ADNI1
# 1         2   NL       bl  011_S_0002  74.3     Male      16.0  ADNI1
# 2         2   NL      m06  011_S_0002  74.3     Male      16.0  ADNI1
# 3         2   NL      m36  011_S_0002  74.3     Male      16.0  ADNI1
# 4         2   NL      m60  011_S_0002  74.3     Male      16.0  ADNI1
# ...     ...  ...      ...         ...   ...      ...       ...    ...
# 22196  7102   NL       sc  341_S_7102   NaN      NaN       NaN  ADNI3
# 22197  7103   NL       sc  013_S_7103   NaN      NaN       NaN  ADNI3
# 22198  7104   NL       sc  153_S_7104   NaN      NaN       NaN  ADNI3
# 22199  7105  MCI       sc  035_S_7105   NaN      NaN       NaN  ADNI3
# 22200  7106  MCI       sc  941_S_7106   NaN      NaN       NaN  ADNI3
#
#          EXAMDATE  Ventricles  ...  NPIK7  NPIK8  NPIK9A  NPIK9B  NPIK9C  \
# 0      2005-08-09    118233.0  ...    NaN    NaN     NaN     NaN     NaN
# 1      2005-08-09    118233.0  ...    NaN    NaN     NaN     NaN     NaN
# 2      2006-06-03    118233.0  ...    NaN    NaN     NaN     NaN     NaN
# 3      2008-08-27    118233.0  ...    NaN    NaN     NaN     NaN     NaN
# 4      2010-09-22    118233.0  ...    NaN    NaN     NaN     NaN     NaN
# ...           ...         ...  ...    ...    ...     ...     ...     ...
# 22196         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
# 22197         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
# 22198         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
# 22199         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
# 22200         NaN         NaN  ...    NaN    NaN     NaN     NaN     NaN
#
#        NPIKTOT  OSA  PREV_DIAG  DIAG_CHANGED  DIAG_GROUP
# 0          NaN  0.0         NL         False       NL-NL
# 1          NaN  0.0         NL         False       NL-NL
# 2          NaN  0.0         NL         False       NL-NL
# 3          NaN  0.0         NL         False       NL-NL
# 4          NaN  0.0         NL         False       NL-NL
# ...        ...  ...        ...           ...         ...
# 22196      NaN  0.0         NL         False       NL-NL
# 22197      NaN  0.0         NL         False       NL-NL
# 22198      NaN  0.0         NL         False       NL-NL
# 22199      NaN  0.0        MCI         False     MCI-MCI
# 22200      NaN  0.0        MCI         False     MCI-MCI
#
# [22201 rows x 66 columns]

# %%
df.columns
# Out:
# Index(['RID', 'DIAG', 'VISCODE2', 'PTID', 'AGE', 'PTGENDER', 'PTEDUCAT',
#        'Phase', 'EXAMDATE', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl',
#        'Hippocampus_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl', 'ICV_bl', 'ABETA', 'TAU', 'PTAU', 'ABETA_bl', 'TAU_bl',
#        'PTAU_bl', 'ratio_Ventricles_bl', 'ratio_Hippocampus_bl',
#        'ratio_WholeBrain_bl', 'ratio_Entorhinal_bl', 'ratio_Fusiform_bl',
#        'ratio_ICV_bl', 'ratio_ABETA_bl', 'ratio_TAU_bl', 'ratio_PTAU_bl',
#        'EXAMDATE_bl', 'duration_in_days', 'Ventricles_reduction_per_year',
#        'Hippocampus_reduction_per_year', 'wholebrain_reduction_per_year',
#        'Entorhinal_reduction_per_year', 'Fusiform_reduction_per_year',
#        'ICV_reduction_per_year', 'ABETA_reduction_per_year',
#        'TAU_reduction_per_year', 'PTAU_reduction_per_year', 'insomnia',
#        'NPIK1', 'NPIK2', 'NPIK3', 'NPIK4', 'NPIK5', 'NPIK6', 'NPIK7', 'NPIK8',
#        'NPIK9A', 'NPIK9B', 'NPIK9C', 'NPIKTOT', 'OSA', 'PREV_DIAG',
#        'DIAG_CHANGED', 'DIAG_GROUP'],
#       dtype='object')

# %%
col_lst = [ target,'Ventricles_reduction_per_year',
       'Hippocampus_reduction_per_year', 'wholebrain_reduction_per_year',
       'Entorhinal_reduction_per_year', 'Fusiform_reduction_per_year',
       'ICV_reduction_per_year']
df1 = df[com_col + col_lst].set_index(com_col).dropna(how='any',axis=0).reset_index()

col_lst_2 = [ target,'ratio_Ventricles_bl', 'ratio_Hippocampus_bl',
       'ratio_WholeBrain_bl', 'ratio_Entorhinal_bl', 'ratio_Fusiform_bl',
       'ratio_ICV_bl']
new_col_name = ['Phase', 'RID', 'VISCODE2', 'PTID','DIAG_GROUP','relative Ventricles volume','relative Hippocampus volume','relative WholeBrain volume',
                'relative Entorhinal volume','relative Fusiform volume','relative ICV volume']
df2 = df[com_col + col_lst_2].set_index(com_col).dropna(how='any',axis=0).reset_index()
df2.columns = new_col_name
col_lst_3 = [ target,'ratio_Ventricles_bl', 'ratio_Hippocampus_bl',
       'ratio_WholeBrain_bl', 'ratio_Entorhinal_bl', 'ratio_Fusiform_bl',
       'ratio_ICV_bl','Ventricles_reduction_per_year',
       'Hippocampus_reduction_per_year', 'wholebrain_reduction_per_year',
       'Entorhinal_reduction_per_year', 'Fusiform_reduction_per_year',
       'ICV_reduction_per_year']
df3 = df[com_col + col_lst_3].set_index(com_col).dropna(how='any',axis=0).reset_index()

# we want to make the model stays simply, therefore we ask the question which is important for the people are involved.
# will it get BETTER or not?
# two groups: MCI-AD or (MCI-MCI, MCI-NL)

label_map_better = { 'MCI-MCI':'MCI-MCIAD','MCI-AD':'MCI-MCIAD','MCI-NL':'MCI-NL','AD-NL':'AD-NLMCI','AD-MCI':'AD-NLMCI','AD-AD':'AD-AD'}
df2_better = df2.copy()
df2_better[target] = df2_better[target].map(label_map_better)

# will it get WORSE or not?
label_map_worse = { 'MCI-NL':'MCI-NLMCI','MCI-MCI':'MCI-NLMCI','MCI-AD':'MCI-AD'}
df2_worse =  df2.copy() 
df2_worse[target] = df2_worse[target].map(label_map_worse)

# %%
df2.groupby(target).count()
# Out:
#             Phase   RID  VISCODE2  PTID  relative Ventricles volume  \
# DIAG_GROUP
# AD-AD        2649  2649      2649  2649                        2649
# AD-MCI         32    32        32    32                          32
# AD-NL           2     2         2     2                           2
# MCI-AD        215   215       215   215                         215
# MCI-MCI      6935  6935      6935  6935                        6935
# MCI-NL         74    74        74    74                          74
# NL-MCI         87    87        87    87                          87
# NL-NL        6942  6942      6942  6942                        6942
#
#             relative Hippocampus volume  relative WholeBrain volume  \
# DIAG_GROUP
# AD-AD                              2649                        2649
# AD-MCI                               32                          32
# AD-NL                                 2                           2
# MCI-AD                              215                         215
# MCI-MCI                            6935                        6935
# MCI-NL                               74                          74
# NL-MCI                               87                          87
# NL-NL                              6942                        6942
#
#             relative Entorhinal volume  relative Fusiform volume  \
# DIAG_GROUP
# AD-AD                             2649                      2649
# AD-MCI                              32                        32
# AD-NL                                2                         2
# MCI-AD                             215                       215
# MCI-MCI                           6935                      6935
# MCI-NL                              74                        74
# NL-MCI                              87                        87
# NL-NL                             6942                      6942
#
#             relative ICV volume
# DIAG_GROUP
# AD-AD                      2649
# AD-MCI                       32
# AD-NL                         2
# MCI-AD                      215
# MCI-MCI                    6935
# MCI-NL                       74
# NL-MCI                       87
# NL-NL                      6942

# %%
df2.shape
# Out:
# (16936, 11)

# %%
np.sum(df2.isna())   # check nan
# Out:
# Phase                          0
# RID                            0
# VISCODE2                       0
# PTID                           0
# DIAG_GROUP                     0
# relative Ventricles volume     0
# relative Hippocampus volume    0
# relative WholeBrain volume     0
# relative Entorhinal volume     0
# relative Fusiform volume       0
# relative ICV volume            0
# dtype: int64

# %%
f, axes = plt.subplots(figsize=(6, 4))
sns.countplot(data=df2, x= target)
plt.tick_params(axis='x',labelrotation=30)
plt.xlabel('Diagnosis changes',fontsize=14)
plt.ylabel('count',fontsize=14)
# Out:
# Text(0, 0.5, 'count')

# %%
lst = ['relative Ventricles volume','relative Hippocampus volume','relative WholeBrain volume',
                'relative Entorhinal volume','relative Fusiform volume','relative ICV volume']

f,axes = plt.subplots(nrows = len(lst)//2 ,ncols=2,figsize=(18,20))
axes = axes.ravel()
#labels = [1,2,3,4,5,6,7,8]
for i in range(len(lst)):
    ax = sns.boxplot(data=df2, y=lst[i],x= target,ax = axes[i])
for ax in f.axes: # rotate x ticks
    #ax.set_xticks(rotation=45, ha='right')
    #ax.set_xticklabels(labels, rotation=45, ha='right')
    ax.tick_params(axis='x',labelrotation=30)

# %% [markdown]
# - AD-NL too little data
#
# - groups:
#     - NL-NL, NL-MCI,
#     - MCI-MCI, MCI-NL, MCI-AD
#     - AD-AD, AD-(MCI+NL)

# %%
df2_better[target].unique()
# Out:
# array([nan, 'AD-AD', 'MCI-MCIAD', 'MCI-NL', 'AD-NLMCI'], dtype=object)

# %%
g1 = df2.loc[df2[target].isin(['NL-NL','NL-MCI'])].reset_index(drop=True)
g2 = df2.loc[df2[target].isin(['MCI-NL','MCI-MCI','MCI-AD'])].reset_index(drop=True)
g2_better = df2_better.loc[df2_better[target].isin(['MCI-NL','MCI-MCIAD'])].reset_index(drop=True)
g2_worse = df2_worse.loc[df2_worse[target].isin(['MCI-NLMCI','MCI-AD'])].reset_index(drop=True)
g3 = df2.loc[df2[target].isin(['AD-MCI','AD-AD'])].reset_index(drop=True)
g3_better = df2_better.loc[df2_better[target].isin(['AD-NLMCI','AD-AD'])].reset_index(drop=True)

# %% [markdown]
# - functions
#     - cv_models(df,drop_lst,target,k): under sampling, NOT SPLIT, scale, pca, models with cross-validation
#     - models(df,drop_lst,target) : under sampling, split, scale, pca, models

# %%
drop_lst = ['Phase', 'RID', 'VISCODE2', 'PTID',target]
k = 10
lst = ['relative Ventricles volume','relative Hippocampus volume','relative WholeBrain volume',
                'relative Entorhinal volume','relative Fusiform volume','relative ICV volume']

# %% [markdown]
# ### is a patient with NL keep NL or not?

# %%
cv_models(g1,drop_lst,target,k)
# Out:
# After undersampling data size is 174 ; Resampled dataset shape Counter({'NL-MCI': 87, 'NL-NL': 87})
#
# 4 principle components are needed to explain 90% of the data
#
# - Using original dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.398
#           - saga_L1, average weighted f1-score of 10-cross validation:0.334
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.401
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.392
#           - saga_L1, average weighted f1-score of 10-cross validation:0.334
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.392
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.461
#           - saga_L1, average weighted f1-score of 10-cross validation:0.334
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.461
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.546
#           - saga_L1, average weighted f1-score of 10-cross validation:0.414
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.546
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.580
#           - saga_L1, average weighted f1-score of 10-cross validation:0.598
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.580
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.592
#           - saga_L1, average weighted f1-score of 10-cross validation:0.607
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.592
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.605
#           - saga_L1, average weighted f1-score of 10-cross validation:0.607
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.605
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.630
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.672
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.632
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.623
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.561
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.536
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.550
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.579
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.582
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.540
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.548
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.547
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.547
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.547
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.579
#           - 10trees. average weighted f1-score of 10-cross validation:0.609
#           - 15trees. average weighted f1-score of 10-cross validation:0.600
#           - 20trees. average weighted f1-score of 10-cross validation:0.599
#           - 25trees. average weighted f1-score of 10-cross validation:0.584
#           - 30trees. average weighted f1-score of 10-cross validation:0.574
#           - 35trees. average weighted f1-score of 10-cross validation:0.565
#           - 40trees. average weighted f1-score of 10-cross validation:0.571
#           - 45trees. average weighted f1-score of 10-cross validation:0.573
#           - 50trees. average weighted f1-score of 10-cross validation:0.561
#           - 55trees. average weighted f1-score of 10-cross validation:0.573
#           - 60trees. average weighted f1-score of 10-cross validation:0.596
#           - 65trees. average weighted f1-score of 10-cross validation:0.578
#           - 70trees. average weighted f1-score of 10-cross validation:0.573
#           - 75trees. average weighted f1-score of 10-cross validation:0.566
#           - 80trees. average weighted f1-score of 10-cross validation:0.583
#           - 85trees. average weighted f1-score of 10-cross validation:0.583
#           - 90trees. average weighted f1-score of 10-cross validation:0.578
#           - 95trees. average weighted f1-score of 10-cross validation:0.572
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.608
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.570
# - Using scaled dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.457
#           - saga_L1, average weighted f1-score of 10-cross validation:0.327
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.457
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.562
#           - saga_L1, average weighted f1-score of 10-cross validation:0.321
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.562
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.599
#           - saga_L1, average weighted f1-score of 10-cross validation:0.364
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.599
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.607
#           - saga_L1, average weighted f1-score of 10-cross validation:0.582
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.607
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.599
#           - saga_L1, average weighted f1-score of 10-cross validation:0.599
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.599
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.599
#           - saga_L1, average weighted f1-score of 10-cross validation:0.599
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.599
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.599
#           - saga_L1, average weighted f1-score of 10-cross validation:0.599
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.599
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.630
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.672
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.632
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.623
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.561
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.536
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.550
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.579
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.582
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.540
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.548
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.547
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.547
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.547
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.579
#           - 10trees. average weighted f1-score of 10-cross validation:0.609
#           - 15trees. average weighted f1-score of 10-cross validation:0.600
#           - 20trees. average weighted f1-score of 10-cross validation:0.599
#           - 25trees. average weighted f1-score of 10-cross validation:0.584
#           - 30trees. average weighted f1-score of 10-cross validation:0.574
#           - 35trees. average weighted f1-score of 10-cross validation:0.565
#           - 40trees. average weighted f1-score of 10-cross validation:0.571
#           - 45trees. average weighted f1-score of 10-cross validation:0.573
#           - 50trees. average weighted f1-score of 10-cross validation:0.561
#           - 55trees. average weighted f1-score of 10-cross validation:0.573
#           - 60trees. average weighted f1-score of 10-cross validation:0.596
#           - 65trees. average weighted f1-score of 10-cross validation:0.578
#           - 70trees. average weighted f1-score of 10-cross validation:0.573
#           - 75trees. average weighted f1-score of 10-cross validation:0.566
#           - 80trees. average weighted f1-score of 10-cross validation:0.583
#           - 85trees. average weighted f1-score of 10-cross validation:0.583
#           - 90trees. average weighted f1-score of 10-cross validation:0.578
#           - 95trees. average weighted f1-score of 10-cross validation:0.572
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.606
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.638
# - Using 4 pca-components:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.459
#           - saga_L1, average weighted f1-score of 10-cross validation:0.327
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.459
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.544
#           - saga_L1, average weighted f1-score of 10-cross validation:0.327
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.544
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.570
#           - saga_L1, average weighted f1-score of 10-cross validation:0.411
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.570
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.575
#           - saga_L1, average weighted f1-score of 10-cross validation:0.575
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.575
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.575
#           - saga_L1, average weighted f1-score of 10-cross validation:0.575
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.575
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.575
#           - saga_L1, average weighted f1-score of 10-cross validation:0.575
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.575
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.575
#           - saga_L1, average weighted f1-score of 10-cross validation:0.575
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.575
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.533
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.607
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.597
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.544
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.554
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.564
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.599
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.591
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.563
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.581
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.575
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.569
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.569
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.569
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.550
#           - 10trees. average weighted f1-score of 10-cross validation:0.596
#           - 15trees. average weighted f1-score of 10-cross validation:0.550
#           - 20trees. average weighted f1-score of 10-cross validation:0.547
#           - 25trees. average weighted f1-score of 10-cross validation:0.569
#           - 30trees. average weighted f1-score of 10-cross validation:0.550
#           - 35trees. average weighted f1-score of 10-cross validation:0.540
#           - 40trees. average weighted f1-score of 10-cross validation:0.545
#           - 45trees. average weighted f1-score of 10-cross validation:0.552
#           - 50trees. average weighted f1-score of 10-cross validation:0.563
#           - 55trees. average weighted f1-score of 10-cross validation:0.573
#           - 60trees. average weighted f1-score of 10-cross validation:0.566
#           - 65trees. average weighted f1-score of 10-cross validation:0.568
#           - 70trees. average weighted f1-score of 10-cross validation:0.549
#           - 75trees. average weighted f1-score of 10-cross validation:0.575
#           - 80trees. average weighted f1-score of 10-cross validation:0.550
#           - 85trees. average weighted f1-score of 10-cross validation:0.556
#           - 90trees. average weighted f1-score of 10-cross validation:0.561
#           - 95trees. average weighted f1-score of 10-cross validation:0.567
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.568
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.604

# %%
# 10trees. average weighted f1-score of 10-cross validation:0.609
n = 10
res = usampling_scale_data(g1,drop_lst,target)     
X = res[0]  # unscaled input
y = res[3]
clf = RandomForestClassifier(n_estimators =n, random_state = 5862)
title_label = '{}-fold crossvalidation random forest ({} trees)'.format(k,n)
feature_importance(X,y,clf,k,title_label)
plt.suptitle('Target: NL-MCI 87; NL-NL 87')
plt.xlabel('relative brain volume',fontsize = 22)
plt.ylabel('Importance',fontsize = 22)
plt.xticks(fontsize=22, rotation=30)
plt.xticks([1, 2,3,4,5,6], ['Ventricles', 'Entorhinal', 'Fusiform','Wholebrain','Hippocampus','ICV'],rotation=20) 
plt.yticks(fontsize=18, rotation=30)

# plot the diagnosis distribution 
df_new = X.copy()
df_new[target] = y
f,axes = plt.subplots(nrows = len(lst)//3,ncols=3,figsize=(15,8))
axes = axes.ravel()

for i in range(len(lst)):
    ax = sns.boxplot(data=df_new, y=lst[i],x= target,ax = axes[i])
    ax.set(xlabel='Diagnosis changes')
for ax in axes:
    plt.xticks(fontsize=18, rotation=30)
# Out:
# After undersampling data size is 174 ; Resampled dataset shape Counter({'NL-MCI': 87, 'NL-NL': 87})
#
# 4 principle components are needed to explain 90% of the data
#
# Features sorted by their score for each estimator

# %%
cv_models(g2,drop_lst,target,k)  # 0.543
# Out:
# After undersampling data size is 222 ; Resampled dataset shape Counter({'MCI-AD': 74, 'MCI-MCI': 74, 'MCI-NL': 74})
#
# 4 principle components are needed to explain 90% of the data
#
# - Using original dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.256
#           - saga_L1, average weighted f1-score of 10-cross validation:0.171
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.256
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.260
#           - saga_L1, average weighted f1-score of 10-cross validation:0.163
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.260
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.355
#           - saga_L1, average weighted f1-score of 10-cross validation:0.155
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.355
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.373
#           - saga_L1, average weighted f1-score of 10-cross validation:0.363
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.373
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.415
#           - saga_L1, average weighted f1-score of 10-cross validation:0.396
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.415
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.408
#           - saga_L1, average weighted f1-score of 10-cross validation:0.408
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.408
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.403
#           - saga_L1, average weighted f1-score of 10-cross validation:0.403
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.403
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.354
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.526
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.506
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.497
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.500
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.525
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.502
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.498
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.525
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.510
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.499
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.502
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.510
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.499
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.472
#           - 10trees. average weighted f1-score of 10-cross validation:0.543
#           - 15trees. average weighted f1-score of 10-cross validation:0.537
#           - 20trees. average weighted f1-score of 10-cross validation:0.538
#           - 25trees. average weighted f1-score of 10-cross validation:0.501
#           - 30trees. average weighted f1-score of 10-cross validation:0.502
#           - 35trees. average weighted f1-score of 10-cross validation:0.517
#           - 40trees. average weighted f1-score of 10-cross validation:0.526
#           - 45trees. average weighted f1-score of 10-cross validation:0.517
#           - 50trees. average weighted f1-score of 10-cross validation:0.525
#           - 55trees. average weighted f1-score of 10-cross validation:0.522
#           - 60trees. average weighted f1-score of 10-cross validation:0.518
#           - 65trees. average weighted f1-score of 10-cross validation:0.510
#           - 70trees. average weighted f1-score of 10-cross validation:0.520
#           - 75trees. average weighted f1-score of 10-cross validation:0.511
#           - 80trees. average weighted f1-score of 10-cross validation:0.503
#           - 85trees. average weighted f1-score of 10-cross validation:0.500
#           - 90trees. average weighted f1-score of 10-cross validation:0.516
#           - 95trees. average weighted f1-score of 10-cross validation:0.512
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.490
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.467
# - Using scaled dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.355
#           - saga_L1, average weighted f1-score of 10-cross validation:0.159
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.355
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.402
#           - saga_L1, average weighted f1-score of 10-cross validation:0.171
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.402
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.391
#           - saga_L1, average weighted f1-score of 10-cross validation:0.353
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.391
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.393
#           - saga_L1, average weighted f1-score of 10-cross validation:0.413
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.393
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.391
#           - saga_L1, average weighted f1-score of 10-cross validation:0.401
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.391
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.391
#           - saga_L1, average weighted f1-score of 10-cross validation:0.391
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.391
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.391
#           - saga_L1, average weighted f1-score of 10-cross validation:0.391
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.391
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.354
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.526
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.506
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.497
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.500
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.525
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.502
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.498
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.525
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.510
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.499
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.502
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.510
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.499
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.472
#           - 10trees. average weighted f1-score of 10-cross validation:0.543
#           - 15trees. average weighted f1-score of 10-cross validation:0.537
#           - 20trees. average weighted f1-score of 10-cross validation:0.530
#           - 25trees. average weighted f1-score of 10-cross validation:0.497
#           - 30trees. average weighted f1-score of 10-cross validation:0.502
#           - 35trees. average weighted f1-score of 10-cross validation:0.517
#           - 40trees. average weighted f1-score of 10-cross validation:0.526
#           - 45trees. average weighted f1-score of 10-cross validation:0.517
#           - 50trees. average weighted f1-score of 10-cross validation:0.525
#           - 55trees. average weighted f1-score of 10-cross validation:0.522
#           - 60trees. average weighted f1-score of 10-cross validation:0.518
#           - 65trees. average weighted f1-score of 10-cross validation:0.510
#           - 70trees. average weighted f1-score of 10-cross validation:0.520
#           - 75trees. average weighted f1-score of 10-cross validation:0.511
#           - 80trees. average weighted f1-score of 10-cross validation:0.503
#           - 85trees. average weighted f1-score of 10-cross validation:0.500
#           - 90trees. average weighted f1-score of 10-cross validation:0.516
#           - 95trees. average weighted f1-score of 10-cross validation:0.512
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.424
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.461
# - Using 4 pca-components:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.351
#           - saga_L1, average weighted f1-score of 10-cross validation:0.163
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.351
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.399
#           - saga_L1, average weighted f1-score of 10-cross validation:0.163
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.399
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.385
#           - saga_L1, average weighted f1-score of 10-cross validation:0.426
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.385
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.378
#           - saga_L1, average weighted f1-score of 10-cross validation:0.381
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.379
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.379
#           - saga_L1, average weighted f1-score of 10-cross validation:0.378
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.379
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.379
#           - saga_L1, average weighted f1-score of 10-cross validation:0.379
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.379
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.379
#           - saga_L1, average weighted f1-score of 10-cross validation:0.379
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.379
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.356
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.439
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.470
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.507
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.480
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.481
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.431
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.459
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.449
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.426
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.467
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.468
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.454
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.440
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.405
#           - 10trees. average weighted f1-score of 10-cross validation:0.418
#           - 15trees. average weighted f1-score of 10-cross validation:0.416
#           - 20trees. average weighted f1-score of 10-cross validation:0.426
#           - 25trees. average weighted f1-score of 10-cross validation:0.439
#           - 30trees. average weighted f1-score of 10-cross validation:0.465
#           - 35trees. average weighted f1-score of 10-cross validation:0.453
#           - 40trees. average weighted f1-score of 10-cross validation:0.461
#           - 45trees. average weighted f1-score of 10-cross validation:0.454
#           - 50trees. average weighted f1-score of 10-cross validation:0.449
#           - 55trees. average weighted f1-score of 10-cross validation:0.450
#           - 60trees. average weighted f1-score of 10-cross validation:0.450
#           - 65trees. average weighted f1-score of 10-cross validation:0.462
#           - 70trees. average weighted f1-score of 10-cross validation:0.444
#           - 75trees. average weighted f1-score of 10-cross validation:0.469
#           - 80trees. average weighted f1-score of 10-cross validation:0.465
#           - 85trees. average weighted f1-score of 10-cross validation:0.463
#           - 90trees. average weighted f1-score of 10-cross validation:0.471
#           - 95trees. average weighted f1-score of 10-cross validation:0.470
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.474
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.469

# %%
cv_models(g2_better,drop_lst,target,k)
# Out:
# After undersampling data size is 148 ; Resampled dataset shape Counter({'MCI-MCIAD': 74, 'MCI-NL': 74})
#
# 3 principle components are needed to explain 90% of the data
#
# - Using original dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.330
#           - saga_L1, average weighted f1-score of 10-cross validation:0.326
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.330
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.324
#           - saga_L1, average weighted f1-score of 10-cross validation:0.341
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.324
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.453
#           - saga_L1, average weighted f1-score of 10-cross validation:0.334
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.453
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.518
#           - saga_L1, average weighted f1-score of 10-cross validation:0.454
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.518
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.533
#           - saga_L1, average weighted f1-score of 10-cross validation:0.513
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.533
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.506
#           - saga_L1, average weighted f1-score of 10-cross validation:0.522
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.506
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.506
#           - saga_L1, average weighted f1-score of 10-cross validation:0.511
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.506
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.493
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.553
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.612
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.592
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.614
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.596
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.610
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.592
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.622
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.600
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.608
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.587
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.607
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.594
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.608
#           - 10trees. average weighted f1-score of 10-cross validation:0.595
#           - 15trees. average weighted f1-score of 10-cross validation:0.597
#           - 20trees. average weighted f1-score of 10-cross validation:0.603
#           - 25trees. average weighted f1-score of 10-cross validation:0.616
#           - 30trees. average weighted f1-score of 10-cross validation:0.617
#           - 35trees. average weighted f1-score of 10-cross validation:0.596
#           - 40trees. average weighted f1-score of 10-cross validation:0.593
#           - 45trees. average weighted f1-score of 10-cross validation:0.599
#           - 50trees. average weighted f1-score of 10-cross validation:0.606
#           - 55trees. average weighted f1-score of 10-cross validation:0.608
#           - 60trees. average weighted f1-score of 10-cross validation:0.609
#           - 65trees. average weighted f1-score of 10-cross validation:0.604
#           - 70trees. average weighted f1-score of 10-cross validation:0.611
#           - 75trees. average weighted f1-score of 10-cross validation:0.602
#           - 80trees. average weighted f1-score of 10-cross validation:0.594
#           - 85trees. average weighted f1-score of 10-cross validation:0.594
#           - 90trees. average weighted f1-score of 10-cross validation:0.597
#           - 95trees. average weighted f1-score of 10-cross validation:0.591
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.527
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.551
# - Using scaled dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.509
#           - saga_L1, average weighted f1-score of 10-cross validation:0.312
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.509
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.562
#           - saga_L1, average weighted f1-score of 10-cross validation:0.326
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.562
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.492
#           - saga_L1, average weighted f1-score of 10-cross validation:0.565
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.492
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.515
#           - saga_L1, average weighted f1-score of 10-cross validation:0.515
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.515
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.518
#           - saga_L1, average weighted f1-score of 10-cross validation:0.518
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.518
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.511
#           - saga_L1, average weighted f1-score of 10-cross validation:0.511
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.511
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.511
#           - saga_L1, average weighted f1-score of 10-cross validation:0.511
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.511
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.493
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.553
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.612
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.592
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.614
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.596
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.610
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.592
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.622
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.600
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.608
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.587
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.607
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.594
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.608
#           - 10trees. average weighted f1-score of 10-cross validation:0.595
#           - 15trees. average weighted f1-score of 10-cross validation:0.597
#           - 20trees. average weighted f1-score of 10-cross validation:0.603
#           - 25trees. average weighted f1-score of 10-cross validation:0.616
#           - 30trees. average weighted f1-score of 10-cross validation:0.617
#           - 35trees. average weighted f1-score of 10-cross validation:0.596
#           - 40trees. average weighted f1-score of 10-cross validation:0.593
#           - 45trees. average weighted f1-score of 10-cross validation:0.599
#           - 50trees. average weighted f1-score of 10-cross validation:0.606
#           - 55trees. average weighted f1-score of 10-cross validation:0.608
#           - 60trees. average weighted f1-score of 10-cross validation:0.609
#           - 65trees. average weighted f1-score of 10-cross validation:0.604
#           - 70trees. average weighted f1-score of 10-cross validation:0.611
#           - 75trees. average weighted f1-score of 10-cross validation:0.602
#           - 80trees. average weighted f1-score of 10-cross validation:0.594
#           - 85trees. average weighted f1-score of 10-cross validation:0.594
#           - 90trees. average weighted f1-score of 10-cross validation:0.597
#           - 95trees. average weighted f1-score of 10-cross validation:0.591
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.655
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.635
# - Using 3 pca-components:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.491
#           - saga_L1, average weighted f1-score of 10-cross validation:0.326
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.491
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.566
#           - saga_L1, average weighted f1-score of 10-cross validation:0.334
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.566
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.545
#           - saga_L1, average weighted f1-score of 10-cross validation:0.550
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.545
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.539
#           - saga_L1, average weighted f1-score of 10-cross validation:0.545
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.539
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.539
#           - saga_L1, average weighted f1-score of 10-cross validation:0.539
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.539
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.539
#           - saga_L1, average weighted f1-score of 10-cross validation:0.539
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.539
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.539
#           - saga_L1, average weighted f1-score of 10-cross validation:0.539
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.539
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.442
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.592
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.569
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.551
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.604
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.647
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.591
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.569
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.599
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.591
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.606
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.612
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.606
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.593
#           - 10trees. average weighted f1-score of 10-cross validation:0.611
#           - 15trees. average weighted f1-score of 10-cross validation:0.640
#           - 20trees. average weighted f1-score of 10-cross validation:0.633
#           - 25trees. average weighted f1-score of 10-cross validation:0.618
#           - 30trees. average weighted f1-score of 10-cross validation:0.650
#           - 35trees. average weighted f1-score of 10-cross validation:0.613
#           - 40trees. average weighted f1-score of 10-cross validation:0.620
#           - 45trees. average weighted f1-score of 10-cross validation:0.620
#           - 50trees. average weighted f1-score of 10-cross validation:0.599
#           - 55trees. average weighted f1-score of 10-cross validation:0.618
#           - 60trees. average weighted f1-score of 10-cross validation:0.618
#           - 65trees. average weighted f1-score of 10-cross validation:0.606
#           - 70trees. average weighted f1-score of 10-cross validation:0.605
#           - 75trees. average weighted f1-score of 10-cross validation:0.593
#           - 80trees. average weighted f1-score of 10-cross validation:0.593
#           - 85trees. average weighted f1-score of 10-cross validation:0.587
#           - 90trees. average weighted f1-score of 10-cross validation:0.600
#           - 95trees. average weighted f1-score of 10-cross validation:0.613
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.541
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.637

# %%
# 30trees. average weighted f1-score of 10-cross validation:0.617
n = 30
res = usampling_scale_data(g2_better,drop_lst,target)     
X = res[0]  # unscaled input
y = res[3]
clf = RandomForestClassifier(n_estimators =n, random_state = 5862)
title_label = '{}-fold crossvalidation random forest ({} trees)'.format(k,n)
feature_importance(X,y,clf,k,title_label)
plt.suptitle('Target: MCI-NL: 74, MCI-MCIAD: 74')
plt.xlabel('relative brain volume',fontsize = 22)
plt.ylabel('Importance',fontsize = 22)
plt.xticks(fontsize=22, rotation=30)
plt.xticks([1, 2,3,4,5,6], ['ICV','Wholebrain', 'Fusiform', 'Entorhinal','Hippocampus','Ventricles'],rotation=20) 
plt.yticks(fontsize=18, rotation=30)
# plot the diagnosis distribution 
df_new = X.copy()
df_new[target] = y
f,axes = plt.subplots(nrows = len(lst)//3,ncols=3,figsize=(12,6))
axes = axes.ravel()
for i in range(len(lst)):
    ax = sns.boxplot(data=df_new, y=lst[i],x= target,ax = axes[i])
    ax.set_xticklabels(['MCI-MCI or MCI-AD','MCI-NL'])
    ax.set(xlabel=' ')
# Out:
# After undersampling data size is 148 ; Resampled dataset shape Counter({'MCI-MCIAD': 74, 'MCI-NL': 74})
#
# 3 principle components are needed to explain 90% of the data
#
# Features sorted by their score for each estimator

# %%
cv_models(g2_worse,drop_lst,target,k)
# Out:
# After undersampling data size is 430 ; Resampled dataset shape Counter({'MCI-AD': 215, 'MCI-NLMCI': 215})
#
# 4 principle components are needed to explain 90% of the data
#
# - Using original dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.333
#           - saga_L1, average weighted f1-score of 10-cross validation:0.333
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.333
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.707
#           - saga_L1, average weighted f1-score of 10-cross validation:0.336
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.707
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.712
#           - saga_L1, average weighted f1-score of 10-cross validation:0.320
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.712
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.710
#           - saga_L1, average weighted f1-score of 10-cross validation:0.728
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.710
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.737
#           - saga_L1, average weighted f1-score of 10-cross validation:0.726
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.737
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.721
#           - saga_L1, average weighted f1-score of 10-cross validation:0.725
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.721
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.718
#           - saga_L1, average weighted f1-score of 10-cross validation:0.723
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.718
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.681
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.719
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.734
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.770
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.763
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.768
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.744
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.743
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.733
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.747
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.726
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.731
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.738
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.731
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.762
#           - 10trees. average weighted f1-score of 10-cross validation:0.772
#           - 15trees. average weighted f1-score of 10-cross validation:0.779
#           - 20trees. average weighted f1-score of 10-cross validation:0.788
#           - 25trees. average weighted f1-score of 10-cross validation:0.781
#           - 30trees. average weighted f1-score of 10-cross validation:0.793
#           - 35trees. average weighted f1-score of 10-cross validation:0.798
#           - 40trees. average weighted f1-score of 10-cross validation:0.784
#           - 45trees. average weighted f1-score of 10-cross validation:0.794
#           - 50trees. average weighted f1-score of 10-cross validation:0.786
#           - 55trees. average weighted f1-score of 10-cross validation:0.789
#           - 60trees. average weighted f1-score of 10-cross validation:0.791
#           - 65trees. average weighted f1-score of 10-cross validation:0.789
#           - 70trees. average weighted f1-score of 10-cross validation:0.789
#           - 75trees. average weighted f1-score of 10-cross validation:0.798
#           - 80trees. average weighted f1-score of 10-cross validation:0.791
#           - 85trees. average weighted f1-score of 10-cross validation:0.793
#           - 90trees. average weighted f1-score of 10-cross validation:0.786
#           - 95trees. average weighted f1-score of 10-cross validation:0.784
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.736
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.727
# - Using scaled dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.724
#           - saga_L1, average weighted f1-score of 10-cross validation:0.336
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.724
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.722
#           - saga_L1, average weighted f1-score of 10-cross validation:0.326
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.722
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.721
#           - saga_L1, average weighted f1-score of 10-cross validation:0.719
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.721
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.723
#           - saga_L1, average weighted f1-score of 10-cross validation:0.723
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.723
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.718
#           - saga_L1, average weighted f1-score of 10-cross validation:0.718
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.718
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.718
#           - saga_L1, average weighted f1-score of 10-cross validation:0.718
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.718
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.718
#           - saga_L1, average weighted f1-score of 10-cross validation:0.718
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.718
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.681
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.719
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.734
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.770
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.763
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.768
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.744
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.743
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.733
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.747
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.726
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.731
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.738
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.731
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.762
#           - 10trees. average weighted f1-score of 10-cross validation:0.772
#           - 15trees. average weighted f1-score of 10-cross validation:0.779
#           - 20trees. average weighted f1-score of 10-cross validation:0.788
#           - 25trees. average weighted f1-score of 10-cross validation:0.781
#           - 30trees. average weighted f1-score of 10-cross validation:0.793
#           - 35trees. average weighted f1-score of 10-cross validation:0.798
#           - 40trees. average weighted f1-score of 10-cross validation:0.784
#           - 45trees. average weighted f1-score of 10-cross validation:0.794
#           - 50trees. average weighted f1-score of 10-cross validation:0.786
#           - 55trees. average weighted f1-score of 10-cross validation:0.789
#           - 60trees. average weighted f1-score of 10-cross validation:0.791
#           - 65trees. average weighted f1-score of 10-cross validation:0.789
#           - 70trees. average weighted f1-score of 10-cross validation:0.789
#           - 75trees. average weighted f1-score of 10-cross validation:0.798
#           - 80trees. average weighted f1-score of 10-cross validation:0.791
#           - 85trees. average weighted f1-score of 10-cross validation:0.793
#           - 90trees. average weighted f1-score of 10-cross validation:0.786
#           - 95trees. average weighted f1-score of 10-cross validation:0.784
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.728
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.727
# - Using 4 pca-components:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.719
#           - saga_L1, average weighted f1-score of 10-cross validation:0.331
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.719
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.714
#           - saga_L1, average weighted f1-score of 10-cross validation:0.720
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.714
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.723
#           - saga_L1, average weighted f1-score of 10-cross validation:0.726
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.723
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.725
#           - saga_L1, average weighted f1-score of 10-cross validation:0.728
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.725
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.730
#           - saga_L1, average weighted f1-score of 10-cross validation:0.730
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.730
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.730
#           - saga_L1, average weighted f1-score of 10-cross validation:0.730
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.730
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.730
#           - saga_L1, average weighted f1-score of 10-cross validation:0.730
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.730
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.659
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.706
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.753
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.768
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.769
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.748
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.740
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.727
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.726
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.721
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.728
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.727
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.727
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.718
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.712
#           - 10trees. average weighted f1-score of 10-cross validation:0.733
#           - 15trees. average weighted f1-score of 10-cross validation:0.744
#           - 20trees. average weighted f1-score of 10-cross validation:0.753
#           - 25trees. average weighted f1-score of 10-cross validation:0.768
#           - 30trees. average weighted f1-score of 10-cross validation:0.764
#           - 35trees. average weighted f1-score of 10-cross validation:0.757
#           - 40trees. average weighted f1-score of 10-cross validation:0.749
#           - 45trees. average weighted f1-score of 10-cross validation:0.745
#           - 50trees. average weighted f1-score of 10-cross validation:0.750
#           - 55trees. average weighted f1-score of 10-cross validation:0.747
#           - 60trees. average weighted f1-score of 10-cross validation:0.751
#           - 65trees. average weighted f1-score of 10-cross validation:0.752
#           - 70trees. average weighted f1-score of 10-cross validation:0.757
#           - 75trees. average weighted f1-score of 10-cross validation:0.759
#           - 80trees. average weighted f1-score of 10-cross validation:0.764
#           - 85trees. average weighted f1-score of 10-cross validation:0.761
#           - 90trees. average weighted f1-score of 10-cross validation:0.764
#           - 95trees. average weighted f1-score of 10-cross validation:0.759
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.706
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.719

# %%
# 75trees. average weighted f1-score of 10-cross validation:0.798

n = 75
res = usampling_scale_data(g2_worse,drop_lst,target)     
X = res[0]  # unscaled input
y = res[3]
clf = RandomForestClassifier(n_estimators =n, random_state = 5862)
title_label = '{}-fold crossvalidation random forest ({} trees)'.format(k,n)
feature_importance(X,y,clf,k,title_label)
plt.suptitle('Target: MCI-AD: 215, MCI-NLMCI: 215')

# plot the diagnosis distribution 
df_new = X.copy()
df_new[target] = y
f,axes = plt.subplots(nrows = len(lst)//3,ncols=3,figsize=(18,12))
axes = axes.ravel()


for i in range(len(lst)):
    ax = sns.boxplot(data=df_new, y=lst[i],x= target,ax = axes[i])
    ax.set_xticklabels(['MCI-AD','MCI-NL or MCI-MCI'])
    ax.set(xlabel='Diagnosis changes')
# Out:
# After undersampling data size is 430 ; Resampled dataset shape Counter({'MCI-AD': 215, 'MCI-NLMCI': 215})
#
# 4 principle components are needed to explain 90% of the data
#
# Features sorted by their score for each estimator

# %% [markdown]
# ### keep this one: is a patient with MCI getting better or not

# %%
cv_models(g3_better,drop_lst,target,k)
# Out:
# After undersampling data size is 68 ; Resampled dataset shape Counter({'AD-AD': 34, 'AD-NLMCI': 34})
#
# 3 principle components are needed to explain 90% of the data
#
# - Using original dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.302
#           - saga_L1, average weighted f1-score of 10-cross validation:0.367
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.302
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.327
#           - saga_L1, average weighted f1-score of 10-cross validation:0.352
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.327
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.508
#           - saga_L1, average weighted f1-score of 10-cross validation:0.304
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.508
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.527
#           - saga_L1, average weighted f1-score of 10-cross validation:0.515
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.527
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.504
#           - saga_L1, average weighted f1-score of 10-cross validation:0.462
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.504
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.484
#           - saga_L1, average weighted f1-score of 10-cross validation:0.470
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.484
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.470
#           - saga_L1, average weighted f1-score of 10-cross validation:0.470
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.470
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.499
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.648
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.715
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.686
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.612
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.608
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.593
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.605
#           - 10trees. average weighted f1-score of 10-cross validation:0.570
#           - 15trees. average weighted f1-score of 10-cross validation:0.649
#           - 20trees. average weighted f1-score of 10-cross validation:0.646
#           - 25trees. average weighted f1-score of 10-cross validation:0.677
#           - 30trees. average weighted f1-score of 10-cross validation:0.646
#           - 35trees. average weighted f1-score of 10-cross validation:0.663
#           - 40trees. average weighted f1-score of 10-cross validation:0.632
#           - 45trees. average weighted f1-score of 10-cross validation:0.650
#           - 50trees. average weighted f1-score of 10-cross validation:0.650
#           - 55trees. average weighted f1-score of 10-cross validation:0.650
#           - 60trees. average weighted f1-score of 10-cross validation:0.617
#           - 65trees. average weighted f1-score of 10-cross validation:0.632
#           - 70trees. average weighted f1-score of 10-cross validation:0.632
#           - 75trees. average weighted f1-score of 10-cross validation:0.662
#           - 80trees. average weighted f1-score of 10-cross validation:0.647
#           - 85trees. average weighted f1-score of 10-cross validation:0.632
#           - 90trees. average weighted f1-score of 10-cross validation:0.646
#           - 95trees. average weighted f1-score of 10-cross validation:0.650
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.545
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.571
# - Using scaled dataset:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.331
#           - saga_L1, average weighted f1-score of 10-cross validation:0.352
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.331
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.529
#           - saga_L1, average weighted f1-score of 10-cross validation:0.336
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.529
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.509
#           - saga_L1, average weighted f1-score of 10-cross validation:0.272
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.509
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.485
#           - saga_L1, average weighted f1-score of 10-cross validation:0.525
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.485
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.447
#           - saga_L1, average weighted f1-score of 10-cross validation:0.447
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.447
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.447
#           - saga_L1, average weighted f1-score of 10-cross validation:0.447
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.447
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.447
#           - saga_L1, average weighted f1-score of 10-cross validation:0.447
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.447
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.499
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.648
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.715
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.686
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.612
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.608
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.593
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.593
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.605
#           - 10trees. average weighted f1-score of 10-cross validation:0.570
#           - 15trees. average weighted f1-score of 10-cross validation:0.649
#           - 20trees. average weighted f1-score of 10-cross validation:0.646
#           - 25trees. average weighted f1-score of 10-cross validation:0.677
#           - 30trees. average weighted f1-score of 10-cross validation:0.646
#           - 35trees. average weighted f1-score of 10-cross validation:0.663
#           - 40trees. average weighted f1-score of 10-cross validation:0.632
#           - 45trees. average weighted f1-score of 10-cross validation:0.650
#           - 50trees. average weighted f1-score of 10-cross validation:0.650
#           - 55trees. average weighted f1-score of 10-cross validation:0.650
#           - 60trees. average weighted f1-score of 10-cross validation:0.617
#           - 65trees. average weighted f1-score of 10-cross validation:0.632
#           - 70trees. average weighted f1-score of 10-cross validation:0.632
#           - 75trees. average weighted f1-score of 10-cross validation:0.662
#           - 80trees. average weighted f1-score of 10-cross validation:0.647
#           - 85trees. average weighted f1-score of 10-cross validation:0.632
#           - 90trees. average weighted f1-score of 10-cross validation:0.646
#           - 95trees. average weighted f1-score of 10-cross validation:0.650
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.705
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.692
# - Using 3 pca-components:
#     - Logistic regression
#        - C = 0.001
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.357
#           - saga_L1, average weighted f1-score of 10-cross validation:0.352
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.357
#        - C = 0.01
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.526
#           - saga_L1, average weighted f1-score of 10-cross validation:0.320
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.526
#        - C = 0.1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.569
#           - saga_L1, average weighted f1-score of 10-cross validation:0.284
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.569
#        - C = 1
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.532
#           - saga_L1, average weighted f1-score of 10-cross validation:0.518
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.532
#        - C = 10
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.518
#           - saga_L1, average weighted f1-score of 10-cross validation:0.518
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.518
#        - C = 100
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.518
#           - saga_L1, average weighted f1-score of 10-cross validation:0.518
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.518
#        - C = 1000
#           - lbfgs_L2, average weighted f1-score of 10-cross validation:0.518
#           - saga_L1, average weighted f1-score of 10-cross validation:0.518
#           - newton-cg_L2, average weighted f1-score of 10-cross validation:0.518
#     - Decision tree
#           - tree depth: 1.000. average weighted f1-score of 10-cross validation:0.501
#           - tree depth: 2.000. average weighted f1-score of 10-cross validation:0.479
#           - tree depth: 3.000. average weighted f1-score of 10-cross validation:0.662
#           - tree depth: 4.000. average weighted f1-score of 10-cross validation:0.631
#           - tree depth: 5.000. average weighted f1-score of 10-cross validation:0.616
#           - tree depth: 6.000. average weighted f1-score of 10-cross validation:0.687
#           - tree depth: 7.000. average weighted f1-score of 10-cross validation:0.696
#           - tree depth: 8.000. average weighted f1-score of 10-cross validation:0.612
#           - tree depth: 9.000. average weighted f1-score of 10-cross validation:0.670
#           - tree depth: 10.000. average weighted f1-score of 10-cross validation:0.690
#           - tree depth: 11.000. average weighted f1-score of 10-cross validation:0.670
#           - tree depth: 12.000. average weighted f1-score of 10-cross validation:0.670
#           - tree depth: 13.000. average weighted f1-score of 10-cross validation:0.670
#           - tree depth: 14.000. average weighted f1-score of 10-cross validation:0.670
#     - Random forest
#           - 5trees. average weighted f1-score of 10-cross validation:0.677
#           - 10trees. average weighted f1-score of 10-cross validation:0.672
#           - 15trees. average weighted f1-score of 10-cross validation:0.649
#           - 20trees. average weighted f1-score of 10-cross validation:0.642
#           - 25trees. average weighted f1-score of 10-cross validation:0.676
#           - 30trees. average weighted f1-score of 10-cross validation:0.690
#           - 35trees. average weighted f1-score of 10-cross validation:0.705
#           - 40trees. average weighted f1-score of 10-cross validation:0.674
#           - 45trees. average weighted f1-score of 10-cross validation:0.690
#           - 50trees. average weighted f1-score of 10-cross validation:0.688
#           - 55trees. average weighted f1-score of 10-cross validation:0.704
#           - 60trees. average weighted f1-score of 10-cross validation:0.690
#           - 65trees. average weighted f1-score of 10-cross validation:0.685
#           - 70trees. average weighted f1-score of 10-cross validation:0.685
#           - 75trees. average weighted f1-score of 10-cross validation:0.685
#           - 80trees. average weighted f1-score of 10-cross validation:0.657
#           - 85trees. average weighted f1-score of 10-cross validation:0.671
#           - 90trees. average weighted f1-score of 10-cross validation:0.671
#           - 95trees. average weighted f1-score of 10-cross validation:0.685
#     - MLP
#           - hidden layer size[50, 50]. average weighted f1-score of 10-cross validation:0.686
#           - hidden layer size[20, 20]. average weighted f1-score of 10-cross validation:0.713

# %%
# 25trees. average weighted f1-score of 10-cross validation:0.677
n = 25
res = usampling_scale_data(g3_better,drop_lst,target)     
X = res[0]  # unscaled input
y = res[3]
clf = RandomForestClassifier(n_estimators =n, random_state = 5862)
title_label = '{}-fold crossvalidation random forest ({} trees)'.format(k,n)
feature_importance(X,y,clf,k,title_label)
plt.suptitle('Target: AD-AD: 34, AD-NLMCI: 34')

# plot the diagnosis distribution 
df_new = X.copy()
df_new[target] = y
f,axes = plt.subplots(nrows = len(lst)//3,ncols=3,figsize=(18,12))
axes = axes.ravel()

for i in range(len(lst)):
    ax = sns.boxplot(data=df_new, y=lst[i],x= target,ax = axes[i])
    ax.set_xticklabels(['AD-AD','AD-NL or AD-MCI'])
    ax.set(xlabel='Diagnosis changes')
# Out:
# After undersampling data size is 68 ; Resampled dataset shape Counter({'AD-AD': 34, 'AD-NLMCI': 34})
#
# 3 principle components are needed to explain 90% of the data
#
# Features sorted by their score for each estimator
